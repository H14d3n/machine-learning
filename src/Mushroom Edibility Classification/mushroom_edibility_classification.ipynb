# %%
import numpy as np
import pandas as pd

# %%
path_mushrooms = "mushrooms.csv"

# %%
df_mushrooms=pd.DataFrame(pd.read_csv(path_mushrooms, sep=';', low_memory=False))

# %%
df_mushrooms
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
df = df_mushrooms

# %%
del df_mushrooms

# %%
df
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df.head(10)
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
# 5     p         15.34         x           g         o                    f
# 6     p         14.85         f           h         o                    f
# 7     p         14.86         x           h         e                    f
# 8     p         12.85         f           g         o                    f
# 9     p         13.55         f           g         e                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# ...

# %%
df.loc[0, "cap-diameter"]
# Out:
# 15.26

# %%
class_series = pd.Series(data=df.loc[:, "class"])
class_series
# Out:
# 0        p
# 1        p
# 2        p
# 3        p
# 4        p
#         ..
# 61064    p
# 61065    p
# 61066    p
# 61067    p
# 61068    p
# Name: class, Length: 61069, dtype: object

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
df_cols = df.columns.tolist()

# %%
df_cols
# Out:
# ['class',
#  'cap-diameter',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-height',
#  'stem-width',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
df_cols[0]
# Out:
# 'class'

# %%
df = df.rename(columns={'class':"class", 'cap-diameter':"cap_diameter", \
                        'cap-shape':"cap_shape", 'cap-surface':"cap_surface", \
                        'cap-color':"cap_color", 'does-bruise-or-bleed':"does_bruise_or_bleed", \
                        'gill-attachment':"gill_attachment", 'gill-spacing':"gill_spacing", \
                        'gill-color':"gill_color", 'stem-height':"stem_height", \
                        'stem-width':"stem_width", 'stem-root':"stem_root", \
                        'stem-surface':"stem_surface", 'stem-color':"stem_color", \
                        'veil-type':"veil_type", 'veil-color':"veil_color", \
                        'has-ring':"has_ring", 'ring-type':"ring_type", \
                        'spore-print-color':"Spore_print_color",'habitat':"habitat", \
                        'season':"season"})

# %%
df
# Out:
#       class  cap_diameter cap_shape cap_surface cap_color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does_bruise_or_bleed gill_attachment gill_spacing gill_color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
df_play = pd.DataFrame([85,96,156,276,398,450], index=[0,1,2,3,4,5], columns=["weight"])

# %%
df_play
# Out:
#    weight
# 0      85
# 1      96
# 2     156
# 3     276
# 4     398
# 5     450

# %%
df_play['Force'] = 0

# %%
df_play
# Out:
#    weight  Force
# 0      85      0
# 1      96      0
# 2     156      0
# 3     276      0
# 4     398      0
# 5     450      0

# %%
df_play['Force'] = df_play['weight'] * 9.81

# %%
df_play
# Out:
#    weight    Force
# 0      85   833.85
# 1      96   941.76
# 2     156  1530.36
# 3     276  2707.56
# 4     398  3904.38
# 5     450  4414.50

# %%
df_play['Temp_Class'] = np.nan

# %%
df_play
# Out:
#    weight    Force  Temp_Class
# 0      85   833.85         NaN
# 1      96   941.76         NaN
# 2     156  1530.36         NaN
# 3     276  2707.56         NaN
# 4     398  3904.38         NaN
# 5     450  4414.50         NaN

# %%
#Force Classification
buckets = [0, 850, 1000, 2000, 4000, 5000]
buckets_name = ['light', 'mid_light', 'heavy', 'super heavy', 'atomical']
df_play['Force_Class'] = pd.cut(df_play['Force'], buckets, labels = buckets_name)

# %%
df_play
# Out:
#    weight    Force  Temp_Class  Force_Class
# 0      85   833.85         NaN        light
# 1      96   941.76         NaN    mid_light
# 2     156  1530.36         NaN        heavy
# 3     276  2707.56         NaN  super heavy
# 4     398  3904.38         NaN  super heavy
# 5     450  4414.50         NaN     atomical

# %%
df_play.dtypes
# Out:
# weight            int64
# Force           float64
# Temp_Class      float64
# Force_Class    category
# dtype: object

# %%
df_play = df_play.astype({"Force": "int"})

# %%
df_play.dtypes
# Out:
# weight            int64
# Force             int32
# Temp_Class      float64
# Force_Class    category
# dtype: object

# %%
df_play["Force"].min()
# Out:
# 833

# %%
df_play["Force"].max()
# Out:
# 4414

# %%
df_play["Force"].unique()
# Out:
# array([ 833,  941, 1530, 2707, 3904, 4414])

# %%
df_play["Force"].describe()
# Out:
# count       6.000000
# mean     2388.166667
# std      1533.146492
# min       833.000000
# 25%      1088.250000
# 50%      2118.500000
# 75%      3604.750000
# max      4414.000000
# Name: Force, dtype: float64

# %%
df_statistics = df_play.describe()

# %%
df_statistics
# Out:
#            weight        Force  Temp_Class
# count    6.000000     6.000000         0.0
# mean   243.500000  2388.166667         NaN
# std    156.271239  1533.146492         NaN
# min     85.000000   833.000000         NaN
# 25%    111.000000  1088.250000         NaN
# 50%    216.000000  2118.500000         NaN
# 75%    367.500000  3604.750000         NaN
# max    450.000000  4414.000000         NaN

# %%
df # Das sind die Mushrooms falls du dich nichtmehr errinerst
# Out:
#       class  cap_diameter cap_shape cap_surface cap_color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does_bruise_or_bleed gill_attachment gill_spacing gill_color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
df.describe()
# Out:
#        cap_diameter   stem_height    stem_width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
import matplotlib.pyplot as plt

path_to_output = r"C:\Users\BFO\Desktop"
df.plot(x="cap_diameter", y="stem_height", kind='scatter')
plt.title('Mushrooms Diameter vs Height')
plt.xlabel('Cap Diameter in cm')
plt.ylabel('Stem Height in cm')
plt.savefig(path_to_output + 'testplot.png', bbox_inches='tight')
plt.show()

# %%
df.gill_spacing.isna().sum()
# Out:
# 25063

# %%
61000 - df.gill_spacing.isna().sum()
# Out:
# 35937

# %%
import sklearn as sl
from sklearn.model_selection import train_test_split as tts

# %%
x = df.drop("class", axis=1)
x
# Out:
#        cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill_attachment gill_spacing gill_color  stem_height  stem_width  \
# ...

# %%
mushroom_dataframe = df

# %%
x.cap_shape=mushroom_dataframe.cap_shape.astype('category').cat.codes
x.cap_surface=mushroom_dataframe.cap_surface.astype('category').cat.codes
x.cap_color=mushroom_dataframe.cap_color.astype('category').cat.codes
x.gill_attachment=mushroom_dataframe.gill_attachment.astype('category').cat.codes
x.does_bruise_or_bleed=mushroom_dataframe.does_bruise_or_bleed.astype('category').cat.codes
x.gill_spacing=mushroom_dataframe.gill_spacing.astype('category').cat.codes
x.gill_color=mushroom_dataframe.gill_color.astype('category').cat.codes
x.stem_root=mushroom_dataframe.stem_root.astype('category').cat.codes
x.stem_surface=mushroom_dataframe.stem_surface.astype('category').cat.codes
x.stem_color=mushroom_dataframe.stem_color.astype('category').cat.codes
x.veil_type=mushroom_dataframe.veil_type.astype('category').cat.codes
x.veil_color=mushroom_dataframe.veil_color.astype('category').cat.codes
x.has_ring=mushroom_dataframe.has_ring.astype('category').cat.codes
x.ring_type=mushroom_dataframe.ring_type.astype('category').cat.codes
x.Spore_print_color=mushroom_dataframe.Spore_print_color.astype('category').cat.codes
x.habitat=mushroom_dataframe.habitat.astype('category').cat.codes
x.season=mushroom_dataframe.season.astype('category').cat.codes
x
# Out:
#        cap_diameter  cap_shape  cap_surface  cap_color  does_bruise_or_bleed  \
# 0             15.26          6            2          6                     0
# 1             16.60          6            2          6                     0
# 2             14.07          6            2          6                     0
# 3             14.17          2            3          1                     0
# 4             14.64          6            3          6                     0
# ...             ...        ...          ...        ...                   ...
# 61064          1.18          5            7         11                     0
# 61065          1.27          2            7         11                     0
# 61066          1.27          5            7         11                     0
# 61067          1.24          2            7         11                     0
# 61068          1.17          5            7         11                     0
#
# ...

# %%
df_label = mushroom_dataframe["class"].copy()

# %%
df_label
# Out:
# 0        p
# 1        p
# 2        p
# 3        p
# 4        p
#         ..
# 61064    p
# 61065    p
# 61066    p
# 61067    p
# 61068    p
# Name: class, Length: 61069, dtype: object

# %%
y=np.ravel(df_label)
y
# Out:
# array(['p', 'p', 'p', ..., 'p', 'p', 'p'], dtype=object)

# %%
#check if dataset label are balanced
df_label.value_counts()
# Out:
# class
# p    33888
# e    27181
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = tts(x,y, test_size = 0.5, random_state=50)

# %%
# from sklearn.datasets import load_iris
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
tree.plot_tree(clf)
# Out:
# [Text(0.5793618073878628, 0.975, 'x[9] <= 8.225\ngini = 0.494\nsamples = 30534\nvalue = [13560, 16974]'),
#  Text(0.33999835092348285, 0.925, 'x[6] <= 0.5\ngini = 0.426\nsamples = 12976\nvalue = [3992, 8984]'),
#  Text(0.21759564643799473, 0.875, 'x[2] <= 3.5\ngini = 0.364\nsamples = 10178\nvalue = [2432, 7746]'),
#  Text(0.09218337730870713, 0.825, 'x[1] <= 0.5\ngini = 0.446\nsamples = 5152\nvalue = [1730, 3422]'),
#  Text(0.037598944591029027, 0.775, 'x[8] <= 3.675\ngini = 0.179\nsamples = 958\nvalue = [95, 863]'),
#  Text(0.02704485488126649, 0.725, 'x[5] <= -0.5\ngini = 0.13\nsamples = 100\nvalue = [93, 7]'),
#  Text(0.021767810026385226, 0.675, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]'),
#  Text(0.032321899736147755, 0.675, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.048153034300791556, 0.725, 'x[8] <= 3.765\ngini = 0.005\nsamples = 858\nvalue = [2, 856]'),
#  Text(0.04287598944591029, 0.675, 'x[7] <= 4.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
# ...

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("mushrooms")
# Out:
# 'mushrooms.pdf'

# %%
test_pred_decision_tree = clf.predict(x_test)

# %%
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
confusion_matrix = metrics.confusion_matrix(y_test,test_pred_decision_tree, labels=["e","p"])
matrix_df = pd.DataFrame(confusion_matrix, index=['e', 'p'], columns=['Predicted edible', 'Predicted poisonous'])

# %%
ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - Decision Tree')
ax.set_xlabel("Predicted label", fontsize =15)
ax.set_ylabel("True Label", fontsize=15)
plt.show()
